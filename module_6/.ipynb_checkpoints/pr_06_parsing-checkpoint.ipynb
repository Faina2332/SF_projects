# %% [markdown]
# План работы:
#
# 1. Парсинг данных с сайна auto.ru
# 2. Разведывательный анализ, визуализация, предоброаботка, работа вс выбросами
# 3. Feachure engineering
# 4. CatBoost
# 5. Выбор алгоритма, подбор гиперпараметров
# 6. Стакинг
# 7. метрика MAPE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Загружаем библиотеки
from pandas import Series
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup  
import requests 

import re
import ast
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

from datetime import datetime, timedelta
from sklearn.preprocessing import StandardScaler

from sklearn.feature_selection import f_classif, mutual_info_classif
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression


from sklearn.metrics import confusion_matrix
from sklearn.metrics import auc, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Загрузим наши тестовые данные
test = pd.read_csv('test.csv')

# %% [markdown]
# ## Анализ тестовых данных

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34686 entries, 0 to 34685
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bodyType              34686 non-null  object
#  1   brand                 34686 non-null  object
#  2   car_url               34686 non-null  object
#  3   color                 34686 non-null  object
#  4   complectation_dict    6418 non-null   object
#  5   description           34686 non-null  object
#  6   engineDisplacement    34686 non-null  object
#  7   enginePower           34686 non-null  object
#  8   equipment_dict        24690 non-null  object
#  9   fuelType              34686 non-null  object
#  10  image                 34686 non-null  object
#  11  mileage               34686 non-null  int64
#  12  modelDate             34686 non-null  int64
#  13  model_info            34686 non-null  object
#  14  model_name            34686 non-null  object
#  15  name                  34686 non-null  object
#  16  numberOfDoors         34686 non-null  int64
#  17  parsing_unixtime      34686 non-null  int64
#  18  priceCurrency         34686 non-null  object
#  19  productionDate        34686 non-null  int64
#  20  sell_id               34686 non-null  int64
#  21  super_gen             34686 non-null  object
#  22  vehicleConfiguration  34686 non-null  object
#  23  vehicleTransmission   34686 non-null  object
#  24  vendor                34686 non-null  object
#  25  Владельцы             34686 non-null  object
#  26  Владение              11995 non-null  object
#  27  ПТС                   34685 non-null  object
#  28  Привод                34686 non-null  object
#  29  Руль                  34686 non-null  object
#  30  Состояние             34686 non-null  object
#  31  Таможня               34686 non-null  object
# dtypes: int64(6), object(26)
# memory usage: 8.5+ MB

# %%
# Посмотрим на пропуски в тестовой выборке
test.isnull().sum()
# Out:
# bodyType                    0
# brand                       0
# car_url                     0
# color                       0
# complectation_dict      28268
# description                 0
# engineDisplacement          0
# enginePower                 0
# equipment_dict           9996
# fuelType                    0
# image                       0
# mileage                     0
# modelDate                   0
# model_info                  0
# model_name                  0
# name                        0
# numberOfDoors               0
# parsing_unixtime            0
# priceCurrency               0
# productionDate              0
# sell_id                     0
# super_gen                   0
# vehicleConfiguration        0
# vehicleTransmission         0
# vendor                      0
# Владельцы                   0
# Владение                22691
# ПТС                         1
# Привод                      0
# Руль                        0
# Состояние                   0
# Таможня                     0
# dtype: int64

# %% [markdown]
# Удалим бесполезную и дублирующуюся информацию, а также удалим столбцы, в которых значительное количество пропусков.

# %%
for_drop = ['car_url', 'complectation_dict', 'equipment_dict', 'image', 'Владение', 'parsing_unixtime', 'super_gen', 
            'sell_id', 'priceCurrency', 'model_info', 'description','name', 'vendor', 'ПТС', 'Таможня']
test.drop(for_drop, axis=1, inplace=True)

# %%
test
# Out:
#                 bodyType  brand       color engineDisplacement enginePower  \
# 0                лифтбек  SKODA       синий            1.2 LTR     105 N12
# 1                лифтбек  SKODA      чёрный            1.6 LTR     110 N12
# 2                лифтбек  SKODA       серый            1.8 LTR     152 N12
# 3                лифтбек  SKODA  коричневый            1.6 LTR     110 N12
# 4                лифтбек  SKODA       белый            1.8 LTR     152 N12
# ...                  ...    ...         ...                ...         ...
# 34681              седан    BMW  коричневый            1.6 LTR     136 N12
# 34682              седан    BMW      чёрный            2.0 LTR     190 N12
# 34683              седан    BMW       серый            2.5 LTR     170 N12
# 34684  внедорожник 5 дв.    BMW  коричневый            2.0 LTR     184 N12
# 34685  внедорожник 5 дв.    BMW      чёрный            3.0 LTR     235 N12
#
#       fuelType  mileage  modelDate model_name  numberOfDoors  productionDate  \
# 0       бензин    74000       2013    OCTAVIA              5            2014
# 1       бензин    60563       2017    OCTAVIA              5            2017
# 2       бензин    88000       2013     SUPERB              5            2014
# 3       бензин    95000       2013    OCTAVIA              5            2014
# 4       бензин    58536       2008    OCTAVIA              5            2012
# ...        ...      ...        ...        ...            ...             ...
# 34681   бензин   115000       2011        3ER              4            2014
# 34682   дизель    98000       2016        5ER              4            2018
# 34683   бензин   360000       1995        5ER              4            1997
# 34684   дизель    90500       2012         X1              5            2013
# 34685   дизель   240000       2006         X5              5            2008
#
#                 vehicleConfiguration vehicleTransmission    Владельцы  \
# 0                 LIFTBACK ROBOT 1.2    роботизированная  3 или более
# 1            LIFTBACK MECHANICAL 1.6        механическая   1 владелец
# 2                 LIFTBACK ROBOT 1.8    роботизированная   1 владелец
# 3             LIFTBACK AUTOMATIC 1.6      автоматическая   1 владелец
# 4             LIFTBACK AUTOMATIC 1.8      автоматическая   1 владелец
# ...                              ...                 ...          ...
# 34681            SEDAN AUTOMATIC 1.6      автоматическая  3 или более
# 34682            SEDAN AUTOMATIC 2.0      автоматическая   1 владелец
# 34683            SEDAN AUTOMATIC 2.5      автоматическая  3 или более
# 34684  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  2 владельца
# 34685  ALLROAD_5_DOORS AUTOMATIC 3.0      автоматическая  3 или более
#
#          Привод   Руль           Состояние
# 0      передний  Левый  Не требует ремонта
# 1      передний  Левый  Не требует ремонта
# 2      передний  Левый  Не требует ремонта
# 3      передний  Левый  Не требует ремонта
# 4      передний  Левый  Не требует ремонта
# ...         ...    ...                 ...
# 34681    задний  Левый  Не требует ремонта
# 34682    полный  Левый  Не требует ремонта
# 34683    задний  Левый  Не требует ремонта
# 34684    полный  Левый  Не требует ремонта
# 34685    полный  Левый  Не требует ремонта
#
# [34686 rows x 17 columns]

# %% [markdown]
# Осталось 19 признаков, далее займемся парсингом данных признаков.

# %%
# Извлечем марки машин которые нужно спарсить
brands = list(test.brand.unique())

# Выберем названия столбцов
columns = list(test.columns)

# %% [markdown]
# Выполним парсинг ссылок на объявления, затем выполним парсинг признаков с данных ссылок. Парсинг ссылок будем выполнять по маркам автомобилей имеющихся в тестовой выборке. Создадим два словаря с данными, из которого будем уже составлять наш трейновый датасет.

# %%
# Собственно парсинг ссылок
# Создадим словарь для данных с колонками 
data_dict = {}
for column in test.columns:
    data_dict[column] = []
data_dict['price'] = []

url = 'https://auto.ru/moskva/cars/'
for car_brand in brands:
    brand_url = url + car_brand + '/used/?page='
    print(car_brand)
    for number in range(1, 5):
        
        response = requests.get(brand_url+str(number), headers={'User-Agent': 'Mozilla/5.0'})
        page = BeautifulSoup(response.text, 'html.parser')
        link_list = page.find_all('a', class_='Link ListingItemTitle-module__link')
        if len(link_list) !=0:
            for link in link_list:
                response = requests.get(link['href'])
                if response.status_code != 200:
                    raise BaseException("response code" + str(response.status_code))
                
                response.encoding = 'utf-8'
                page = BeautifulSoup(response.text, 'html.parser')
                first_dict = ast.literal_eval(str(page.find_all('script', attrs = {'type':'application/ld+json'})[0])[35:-9])
              
                data_dict['brand'].append(first_dict['brand'])
                data_dict['bodyType'].append(first_dict['bodyType'])
                data_dict['color'].append(first_dict['color'])
                data_dict['engineDisplacement'].append(first_dict['vehicleEngine']['engineDisplacement'])
                data_dict['enginePower'].append(first_dict['vehicleEngine']['enginePower'])
                data_dict['fuelType'].append(first_dict['fuelType'])
                data_dict['modelDate'].append(first_dict['modelDate'])
                try: 
                    data_dict['model_name'].append(first_dict['name'].split(' ')[1])
                except KeyError:
                    data_dict['model_name'].append(np.nan)
                data_dict['numberOfDoors'].append(first_dict['numberOfDoors'])
                data_dict['productionDate'].append(first_dict['productionDate'])
                data_dict['vehicleConfiguration'].append(first_dict['vehicleConfiguration'])
                data_dict['vehicleTransmission'].append(first_dict['vehicleTransmission'])
                           
                data_dict['mileage'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_kmAge")[0].text.replace('\xa0', '')[6:-2])
                try:
                    data_dict['Владельцы'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_ownersCount")[0].text.replace('\xa0', '')[9:-9])
                except:
                    data_dict['Владельцы'].append(np.nan)

                data_dict['Привод'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_drive")[0].text[6:])
                data_dict['Руль'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_wheel")[0].text[4:])
                data_dict['Состояние'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_state")[0].text[9:])
                try:
                    data_dict['price'].append(first_dict['offers']['price'])
                except KeyError:
                    data_dict['price'].append(np.nan)

        else:
            break
# Out:
# SKODA
# AUDI
# HONDA
# VOLVO
# BMW
# NISSAN
# INFINITI
# MERCEDES
# TOYOTA
# LEXUS
# VOLKSWAGEN
# MITSUBISHI

# %%
data_dict_1_4=data_dict

# %%
#data_dict_1_5=data_dict

# %%
with open('data1.json', 'w') as fp:
    json.dump(data_dict_1_5, fp)

# %%
# Собственно парсинг ссылок
# Создадим словарь для данных с колонками 
data_dict = {}
for column in test.columns:
    data_dict[column] = []
data_dict['price'] = []

url = 'https://auto.ru/moskva/cars/'
for car_brand in brands:
    brand_url = url + car_brand + '/used/?page='
    print(car_brand)
    for number in range(5, 11):
        
        response = requests.get(brand_url+str(number), headers={'User-Agent': 'Mozilla/5.0'})
        page = BeautifulSoup(response.text, 'html.parser')
        link_list = page.find_all('a', class_='Link ListingItemTitle-module__link')
        if len(link_list) !=0:
            for link in link_list:
                response = requests.get(link['href'])
                if response.status_code != 200:
                    raise BaseException("response code" + str(response.status_code))
               
                response.encoding = 'utf-8'
                page = BeautifulSoup(response.text, 'html.parser')
                first_dict = ast.literal_eval(str(page.find_all('script', attrs = {'type':'application/ld+json'})[0])[35:-9])
              
                data_dict['brand'].append(first_dict['brand'])
                data_dict['bodyType'].append(first_dict['bodyType'])
                data_dict['color'].append(first_dict['color'])
                data_dict['engineDisplacement'].append(first_dict['vehicleEngine']['engineDisplacement'])
                data_dict['enginePower'].append(first_dict['vehicleEngine']['enginePower'])
                data_dict['fuelType'].append(first_dict['fuelType'])
                data_dict['modelDate'].append(first_dict['modelDate'])
                try: 
                    data_dict['model_name'].append(first_dict['name'].split(' ')[1])
                except KeyError:
                    data_dict['model_name'].append(np.nan)
                data_dict['numberOfDoors'].append(first_dict['numberOfDoors'])
                data_dict['productionDate'].append(first_dict['productionDate'])
                data_dict['vehicleConfiguration'].append(first_dict['vehicleConfiguration'])
                data_dict['vehicleTransmission'].append(first_dict['vehicleTransmission'])
                           
                data_dict['mileage'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_kmAge")[0].text.replace('\xa0', '')[6:-2])
                try:
                    data_dict['Владельцы'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_ownersCount")[0].text.replace('\xa0', '')[9:-9])
                except:
                    data_dict['Владельцы'].append(np.nan)

                data_dict['Привод'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_drive")[0].text[6:])
                data_dict['Руль'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_wheel")[0].text[4:])
                data_dict['Состояние'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_state")[0].text[9:])
                try:
                    data_dict['price'].append(first_dict['offers']['price'])
                except KeyError:
                    data_dict['price'].append(np.nan)

        else:
            break
# Out:
# SKODA
# AUDI
# HONDA
# VOLVO
# BMW
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     696         try:
# --> 697             self.chunk_left = int(line, 16)
#     698         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     436             try:
# --> 437                 yield
#     438
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     700             self.close()
# --> 701             raise httplib.IncompleteRead(line)
#     702
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     792             if self._original_response:
# --> 793                 self._original_response.close()
#     794
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     454                 # This includes IncompleteRead.
# --> 455                 raise ProtocolError("Connection broken: %r" % e, e)
#     456
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# <ipython-input-10-6a9f70a97dd9> in <module>
#      17         if len(link_list) !=0:
#      18             for link in link_list:
# ---> 19                 response = requests.get(link['href'])
#      20                 if response.status_code != 200:
#      21                     raise BaseException("response code" + str(response.status_code))
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     752                         yield chunk
#     753                 except ProtocolError as e:
# --> 754                     raise ChunkedEncodingError(e)
#     755                 except DecodeError as e:
#     756                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))

# %%
page

# %%
for i in data_dict['bodyType']:
    print(i)
# Out:
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# хэтчбек 5 дв.
# универсал 5 дв.
# лифтбек
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# компактвэн
# внедорожник 5 дв.
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# универсал 5 дв.
# лифтбек
# лифтбек
# седан
# лифтбек
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# универсал 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# универсал 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# универсал 5 дв.
# лифтбек
# универсал 5 дв.
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# хэтчбек 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# универсал 5 дв.
# лифтбек
# лифтбек
# лифтбек
# компактвэн
# внедорожник 5 дв.
# лифтбек
# лифтбек
# лифтбек
# лифтбек
# внедорожник 5 дв.
# лифтбек
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# лифтбек
# внедорожник 5 дв.
# универсал 5 дв.
# лифтбек
# лифтбек
# седан
# седан
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# лифтбек
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# лифтбек
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# купе
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# седан
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# хэтчбек 5 дв.
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# лифтбек
# седан
# лифтбек
# лифтбек
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# купе
# седан
# купе
# седан
# внедорожник 5 дв.
# лифтбек
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# седан
# хэтчбек 5 дв.
# лифтбек
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# седан
# седан
# универсал 5 дв.
# седан
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# лифтбек
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# лифтбек
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# лифтбек
# седан
# внедорожник 5 дв.
# купе
# внедорожник 5 дв.
# купе
# седан
# купе
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# купе
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# лифтбек
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 3 дв.
# седан
# внедорожник 5 дв.
# седан
# лифтбек
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# лифтбек
# седан
# лифтбек
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# минивэн
# седан
# купе
# седан
# хэтчбек 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 3 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# хэтчбек 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# хэтчбек 3 дв.
# родстер
# компактвэн
# седан
# седан
# внедорожник 5 дв.
# компактвэн
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# микровэн
# внедорожник 5 дв.
# кабриолет
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# минивэн
# внедорожник 5 дв.
# седан
# компактвэн
# минивэн
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 3 дв.
# хэтчбек 5 дв.
# кабриолет
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# хэтчбек 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# седан
# универсал 5 дв.
# хэтчбек 5 дв.
# минивэн
# внедорожник 5 дв.
# хэтчбек 3 дв.
# купе
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# компактвэн
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# компактвэн
# внедорожник 5 дв.
# купе
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# хэтчбек 3 дв.
# седан
# хэтчбек 3 дв.
# компактвэн
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# хэтчбек 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# купе
# внедорожник 5 дв.
# купе
# седан
# хэтчбек 5 дв.
# седан
# хэтчбек 5 дв.
# седан
# универсал 5 дв.
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# хэтчбек 3 дв.
# седан
# компактвэн
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 3 дв.
# хэтчбек 5 дв.
# седан
# купе
# внедорожник 5 дв.
# компактвэн
# седан
# купе
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# купе
# хэтчбек 5 дв.
# родстер
# хэтчбек 5 дв.
# хэтчбек 3 дв.
# седан
# седан
# микровэн
# хэтчбек 5 дв.
# седан
# седан
# хэтчбек 3 дв.
# минивэн
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# хэтчбек 3 дв.
# внедорожник 5 дв.
# седан
# седан
# универсал 5 дв.
# внедорожник 3 дв.
# седан
# седан
# хэтчбек 5 дв.
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# компактвэн
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# седан
# хэтчбек 5 дв.
# седан
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 3 дв.
# внедорожник 5 дв.
# купе
# компактвэн
# хэтчбек 3 дв.
# хэтчбек 5 дв.
# хэтчбек 3 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# компактвэн
# хэтчбек 5 дв.
# внедорожник 3 дв.
# седан
# седан
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# седан
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# хэтчбек 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# универсал 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# седан
# универсал 5 дв.
# седан
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# седан
# универсал 5 дв.
# хэтчбек 3 дв.
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# внедорожник 5 дв.
# хэтчбек 3 дв.
# внедорожник 5 дв.
# седан
# универсал 5 дв.
# седан
# универсал 5 дв.
# седан
# универсал 5 дв.
# седан
# седан
# седан
# седан
# седан
# универсал 5 дв.
# универсал 5 дв.
# хэтчбек 5 дв.
# универсал 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# седан
# хэтчбек 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# хэтчбек 5 дв.
# седан
# седан
# хэтчбек 3 дв.
# седан
# универсал 5 дв.
# седан
# седан
# седан
# универсал 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# седан
# седан
# седан
# кабриолет
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# внедорожник 5 дв.
# седан
# хэтчбек 5 дв.
# хэтчбек 5 дв.
# лифтбек
# седан
# купе
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# седан
# купе
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# лифтбек
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# седан
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# лифтбек
# купе
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# лифтбек
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# купе
# седан
# внедорожник 5 дв.
# седан
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# универсал 5 дв.
# внедорожник 5 дв.
# седан
# внедорожник 5 дв.
# седан
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан
# седан
# родстер
# купе
# внедорожник 5 дв.
# седан
# седан
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# хэтчбек 5 дв.
# седан
# внедорожник 5 дв.
# хэтчбек 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# внедорожник 5 дв.
# седан

# %%
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
url = 'https://auto.ru/moskva/cars/used/'
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
page = BeautifulSoup(response.text, 'html.parser')
link_list = page.find_all('a', class_='Link ListingItemTitle-module__link')

# %%
url_1 = link_list[0]['href']
response = requests.get(url_1)
response.encoding = 'utf-8'
page = BeautifulSoup(response.text, 'html.parser')
first_dict = ast.literal_eval(str(page.find_all('script', attrs = {'type':'application/ld+json'})[0])[35:-9])
second_dict = [info.text for info in page.find_all('span', class_="CardInfoRow__cell")]

# %%
data_dict = {}
for column in test.columns:
    data_dict[column] = []
data_dict['price'] = []

# %%
import json  
from pprint import pprint 
with open('data.json') as fp:
   data_dict = json.load(fp)

# %%
len(data_dict['car_url'])
# Out:
# 94752

# %%
len(data_dict['price'])
# Out:
# 94752

# %%
len(data_dict['model_name'])
# Out:
# 34875

# %%
url = 'https://auto.ru/moskva/cars/'
for car_brand in brands:
    brand_url = url + car_brand + '/used/?page='
    cars_urls[car_brand] = []
    print(car_brand)
    for number in range(1, 100):
        response = requests.get(brand_url+str(number), headers={'User-Agent': 'Mozilla/5.0'})
        page = BeautifulSoup(response.text, 'html.parser')
        link_list = page.find_all('a', class_='Link ListingItemTitle-module__link')
        if len(link_list) !=0:
            for link in link_list:
                cars_urls[car_brand].append(link['href'])
        else:
            break
with open('data.json', 'w') as fp:
    json.dump(cars_urls, fp)

# %%
import time

# %%
for i in range(1,len(data_dict['car_url']),100):
    for url in data_dict['car_url'][i: i+100]:
        response = requests.get(url)
        if response.status_code != 200:
            print('Ожидаю 0.5 секунды...')  
            time.sleep(0.5)
            response = requests.get(url)
            
        response.encoding = 'utf-8'
        page = BeautifulSoup(response.text, 'html.parser')
        first_dict = ast.literal_eval(str(page.find_all('script', attrs = {'type':'application/ld+json'})[0])[35:-9])
              
        try:
            data_dict['brand'].append(first_dict['brand'])
        except:
            data_dict['brand'].append(np.nan)
        try:
            data_dict['bodyType'].append(first_dict['bodyType'])
        except:
            data_dict['bodyType'].append(np.nan)
        try:
            data_dict['color'].append(first_dict['color'])
        except:
            data_dict['color'].append(np.nan)
        try:
            data_dict['engineDisplacement'].append(first_dict['vehicleEngine']['engineDisplacement'])
        except:
            data_dict['engineDisplacement'].append(np.nan)
        try:
            data_dict['enginePower'].append(first_dict['vehicleEngine']['enginePower'])
        except:
            data_dict['enginePower'].append(np.nan)
        try:
            data_dict['fuelType'].append(first_dict['fuelType'])
        except:
            data_dict['fuelType'].append(np.nan)
        try:
            data_dict['modelDate'].append(first_dict['modelDate'])
        except:
            data_dict['modelDate'].append(np.nan)
        try: 
            data_dict['modelName'].append(first_dict['name'].split(' ')[1])
        except KeyError:
            data_dict['modelName'].append(np.nan)
        try:
            data_dict['numberOfDoors'].append(first_dict['numberOfDoors'])
        except:
            data_dict['numberOfDoors'].append(np.nan)
        try:
            data_dict['productionDate'].append(first_dict['productionDate'])
        except:
            data_dict['productionDate'].append(np.nan)    
        try:
            data_dict['vehicleConfiguration'].append(first_dict['vehicleConfiguration'])
        except:
            data_dict['vehicleConfiguration'].append(np.nan)
        try:
            data_dict['vehicleTransmission'].append(first_dict['vehicleTransmission'])  
        except:
            data_dict['vehicleTransmission'].append(np.nan)
        try:
            data_dict['mileage'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_kmAge")[0].text.replace('\xa0', '')[6:-2])
        except:
            data_dict['mileage'].append(np.nan)
        try:
            data_dict['Владельцы'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_ownersCount")[0].text.replace('\xa0', '')[9:-9])
        except:
            data_dict['Владельцы'].append(np.nan)
        try:
            data_dict['Привод'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_drive")[0].text[6:])
        except:
            data_dict['Привод'].append(np.nan)
        try:
            data_dict['Руль'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_wheel")[0].text[4:])
        except:
            data_dict['Руль'].append(np.nan)
        try:
            data_dict['Состояние'].append(page.find_all('li', class_="CardInfoRow CardInfoRow_state")[0].text[9:])
        except:
            data_dict['Состояние'].append(np.nan)
        try:
            data_dict['price'].append(first_dict['offers']['price'])
        except:
            data_dict['price'].append(np.nan)
    with open('data.json', 'w') as fp:
        json.dump(data_dict, fp)
    print('+100')
# Out:
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100

# %%
for i in range(1,len(data_dict['car_url']),100):
    for url in data_dict['car_url'][i: i+100]:
        response = requests.get(url)
        if response.status_code != 200:
            print('Ожидаю 0.5 секунды...')  
            time.sleep(0.5)
            response = requests.get(url)
            
        response.encoding = 'utf-8'
        page = BeautifulSoup(response.text, 'html.parser')
        first_dict = ast.literal_eval(str(page.find_all('script', attrs = {'type':'application/ld+json'})[0])[35:-9])
              
        try: 
            data_dict['model_name'].append(first_dict['name'].split(' ')[1])
        except KeyError:
            data_dict['model_name'].append(np.nan)

    with open('data.json', 'w') as fp:
        json.dump(data_dict, fp)
    print('+100')
# Out:
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# +100
# Ожидаю 0.5 секунды...
# +100
# +100

# %%
len(data_dict['brand'])
# Out:
# 4109

# %%
len(data_dict['price'])
# Out:
# 4109

# %%
len(data_dict['model_name'])
# Out:
# 34375

# %%
data_dict.keys()
# Out:
# dict_keys(['bodyType', 'brand', 'car_url', 'color', 'engineDisplacement', 'enginePower', 'fuelType', 'mileage', 'modelDate', 'numberOfDoors', 'productionDate', 'vehicleConfiguration', 'vehicleTransmission', 'Владельцы', 'Привод', 'Руль', 'Состояние', 'price', 'model_name'])
